# %% [markdown]
# # The State of JavaScript
# ## and the Importance of Coding Standards
#
# <br>
#
# `<Title Subject to change>`

# %% [markdown]
# <br>

# %% [markdown]
# Mayur Deshmukh

# %% [markdown]
# ## Who Am I?

# %% [markdown]
# - Web Developer @ Red Hat
# - UX Designer
# - Web Evangelist (\*_Self proclaimed_\*)

# %% [markdown]
# That's enough about me. Let's just jump into it.

# %% [markdown]
# *before we start*

# %% [markdown]
# ### A quick quiz

# %% [markdown]
# ### Name these...

# %% [markdown]
# It will help me gauge the audience

# %% [markdown]
# ![HTML CSS JS](./media/html-css-js.jpg)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ```js
# HTML5 && CSS3 && JS
# ```
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <img style="margin-left: auto; margin-right: auto;" src="attachment:image.png">

# %% [markdown]
# <br>
# <br>
#
# ```
# stackoverflow (SO)
#
# ```

# %% [markdown]
# <div class="quick-fire">
#
# | &nbsp; | &nbsp; | &nbsp; | &nbsp; |
# |--|--|--|--|
# | ![angular](./media/angular.png) | ![react](./media/react.png) | ![node](./media/nodejs.png) | ![python](./media/python.png) |
# | ![vscode](./media/vscode.jpg) | ![jquery](./media/jquery.png) | ![mongodb](./media/mongodb.png) | ![npm](./media/npm.jpg) |
#
# </div>

# %% [markdown]
# ## Agenda

# %% [markdown]
# 1. What?
# 2. Why?
# 3. How?

# %% [markdown]
# <br><br>

# %% [markdown]
# 4. Some random stuff

# %% [markdown]
# ## What is ECMAScript??

# %% [markdown]
# - Standard version of JavaScript
# - Defined in ECMA-262

# %% [markdown]
# > ```
# > ES5 --→ ES2015 --→ ES2016 --→ ES2017 --→ ES2018 --→ ES2019
# > ```

# %% [markdown]
# ## Wait, but why JavaScript?

# %% [markdown]
# - Most popular programming language ever
# - Powers 95.2% of the web front-end
# - The only language that runs in s browser
# - Ideal for cross platform development
# - Write once, run anywhere
# - Wide community and support

# %% [markdown]
# - Wide community support
#     - Most popular language on SO: `67.8%`
#     - Most popular tool on SO: `49.9%`
# <br><br>
#
#     <small>Ref: https://insights.stackoverflow.com/survey/2019#technology</small>

# %% [markdown]
# - Can be used for developing any kind of applications
#     - Desktop Web Apps
#     - Mobile Web Apps
#     - Native Apps
#     - PWAs
#     - Games
#     - VR

# %% [markdown]
# - Standardized, and actively improved (TC39 of ECMA)
#
#
# - The most versatile and flexible language ever
#     - Supports multiple paradigms
#         - OOP, Functional, Imperative, etc.

# %% [markdown]
# TC39 = ECMA Technical Committee

# %% [markdown]
# ## But...

# %% [markdown]
# <img src="attachment:image.png" style="height: 30%; width: 30%; margin-left: auto; margin-right: auto">

# %% [markdown]
# <p style="text-align: center">Coincidence?</p>

# %% [markdown]
# <img src="attachment:image.png" style="height: 50%; width: 40%; margin-left: auto; margin-right: auto">

# %% [markdown]
# ## Two Kinds of people

# %% [markdown]
# ```js
# if (condition)
# {
#     // some statements
# }
# ```

# %% [markdown]
# ```js
# if (condition) {
#     // some statements
# }
# ```

# %%
# Wat 
from IPython.display import HTML

video_path = './media/wat.mp4'

HTML("""
<video width="840" height="460" controls="">
<source src="{0}">
</video>
""".format(video_path))
# Out:
# <video width="840" height="460" controls="">
# <source src="./media/wat.mp4">
# </video>

# %% [markdown]
# Source: https://www.destroyallsoftware.com/talks/wat

# %% [markdown]
# <img style="margin-left: auto; margin-right: auto; width: 60%;" src="./media/code_quality.png">

# %% [markdown]
# <small style="display: block; width: 100%; text-align: center;">Source: https://xkcd.com/1513/</small>

# %% [markdown]
# > ### With great power comes great responsibility
# >
# > &mdash; Uncle Ben (Every Spider-Man movie ever)

# %% [markdown]
# ## The Python Philosophy

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# <small>PEP20: https://www.python.org/dev/peps/pep-0020/</small>
#
#
# <small>PEP8: https://www.python.org/dev/peps/pep-0008/</small>

# %% [markdown]
# Zen of Python created by Tim Peters

# %% [markdown]
# ### What about JavaScript?

# %% [markdown]
# - Unfortunately, ECMA-292 does not provide any standard style guide
#
#
# - But, there are some globally accepted style guides used by major companies
#
#     - ✨ Airbnb JavaScript Style Guide
#         - https://github.com/airbnb/javascript
#
#     - Google JavaScript Style Guide
#         - https://google.github.io/styleguide/jsguide.html
#
#     - Idiomatic JavaScript Style Guide
#         - https://github.com/rwaldron/idiomatic.js/
#
#     - JavaScript Standard Style Guide
#         - https://standardjs.com

# %% [markdown]
# ### Linters to the resque...

# %% [markdown]
# - **ESLint**
#
#     - A pluggable and configurable linter for identifying and reporting on patterns found in ECMAScript/JavaScript code
#
#     - Works great with modern IDEs (e.g. VS Code)
#
#     - Useful for enforcing coding standards in a JavaScript codebase

# %% [markdown]
# <small>Ref: https://eslint.org/docs/rules/</small>

# %% [markdown]
# #### Before I end my talk,
#
# ## A few keywords to explore…

# %% [markdown]
# - SPA
#
#
# - Serverless
#
#
# - Microservices
#
#
# - Micro front-end
#
#
# - PWAs
#
#
# - Containerized applications
#
#
# - TypeScript

# %% [markdown]
# # Thank you

# %% [markdown]
# <br>

# %% [markdown]
# <img style="width: 50%; height: 50%; margin-left: auto; margin-right: auto;" src="attachment:Avatar.png">

# %% [markdown]
# ## Mayur Deshmukh
#
# https://deshmukhmayur.com
#
# - **mayurdeshmukh198\@gmail.com**
# - ig: **@deshmukhmayur**
# - twitter: **@deshmukhmayur_**
